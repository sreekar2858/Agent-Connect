# %%
import websockets
import asyncio

# Test client
async with websockets.connect("ws://localhost:8001/ws") as ws:
    await ws.send("test")
    print(await ws.recv())

# %%
import os
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 os.path.splitext(os.path.basename(__file__))[0]
#
# NameError: name '__file__' is not defined
